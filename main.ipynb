# %%
#Scrapping codde

from googleapiclient.discovery import build
import json

service_name="youtube"
version="v3"
api_key="AIzaSyDf1ti1zpkxib2B08Vv44-u6m5e923Bx1g"
youtube=build(service_name,version,developerKey=api_key)

video_details=[]
playlist_ids=[]
channel_ids=["UCIPPMRA040LQr5QPyJEbmXA",#mr beast
             "UC85aYbNSFjsJdxfpxgQr8tA",#judo slot
             "UC9YydG57epLqxA9cTzZXSeQ",#cod
]


for channel_id in channel_ids:
    try:
        playlist_request = youtube.playlists().list(
            part="snippet,contentDetails",
            channelId=channel_id,
            maxResults=100
        )
        playlist_response = playlist_request.execute()

        for item in playlist_response['items']:
            if 'id' in item:
                playlist_ids.append(item['id'])

    except Exception as e:
        print(F"Error:{e}")
print(f"Playlist IDs: {playlist_ids}")

for playlist_id in playlist_ids:
    next_page_token=None
    video_count=0
    while True:
        try:
            playlist_items_request = youtube.playlistItems().list(
                    part="snippet,contentDetails",
                    maxResults=2,
                    playlistId=playlist_id,
                    pageToken=next_page_token
                )
            playlist_items_response = playlist_items_request.execute()
            for item in playlist_items_response['items']:
                if video_count < 2:
                    video_id = item['contentDetails']['videoId']
                    video_details_request = youtube.videos().list(
                        part="snippet,contentDetails,statistics",
                        id=video_id
                    )
                    video_details_response = video_details_request.execute()


                    video_details.append(video_details_response)
                    video_count += 1

            next_page_token = playlist_items_response.get('nextPageToken')
            if not next_page_token or video_count >= 2:
                break

        except Exception as e:
            print(f"An error occurred while fetching video details: {e}")
            break


with open('gaming.json', 'w') as file:
    json.dump(video_details, file, indent=4)

print("Video details have been saved")

# %% [markdown]
#  sports.json:
#     "UC_WKb6N9iTGc77hxwXLDrbA", # Sony sports Network
#     "UCTl3QQTvqHFjurroKxexy2Q", # Olympics
#     "UC14UlmYlSNiQCBe9Eookf_A", # FC barcelona
#     "UCWV3obpZVGgJ3j9FVhEjF2Q", # Real madrid
#     "UCmqfX0S3x0I3uwLkPdpX03w" # Star sports english
# news.json:
#     "UCYPvAwZP8pZhSMW8qs7cVCw", #India today
#     "UC16niRr50-MSBwiO3YDb3RA" ,#BCC
#     "UCZFMm1mMw0F81Z37aaEzTUA", #ndtv
#     "UCQXHTFnQYFTqN0MqmNh9EIA", #bcc wwordls service
#     "UCJEDFSxHHOW1PpBccdSxOTA" #indian express
# animals.json:
#     "UCwmZiChSryoWQCZMIQezgTg", # bcc earth
#     "UCpVm7bg6pXKo1Pr6k5kxG9A", #national geographic
#     "UCbq-4OJxnziD3awH-aTezeA",#real wild
#     "UCQtW2oz8ec8pHjjxawujNjg", #free documentary nature
#     "UCz73YrQjemoqx6ZvVfJDAew" #wildlife
# coding.json:
#     "UCqrILQNl5Ed9Dz6CGMyvMTQ",#clever programmer
#     "UCWv7vMbMWH4-V0ZXdmDpPBA",#progr with mosh
#     "UC29ju8bIPH5as8OGnQzwJyA",#trvaersy media
#     "UCxX9wt5FWQUAAz4UrysqK9A"#cs dojo
# food.json:
#     "UCiAq_SU0ED1C6vWFMnw8Ekg",# the food range
#     "UCcAd5Np7fO8SeejB1FVKcYw",#    best ever food review
#     "UCIEv3lZ_tNXHzL3ox-_uUGQ",#gordon ramsy
#     "UCyEd6QBSgat5kkC6svyjudA",#mark weins
# gaming.json:
#     "UCIPPMRA040LQr5QPyJEbmXA",#mr beast
#     "UC85aYbNSFjsJdxfpxgQr8tA",#judo slot
#     "UC9YydG57epLqxA9cTzZXSeQ",#cod

# %%
# Inserting the json files into s3 bucket

import boto3
access_key="AKIA2ZIONHLCAOUANT4I"
secret_access_key="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"
s3_client=boto3.client('s3',aws_access_key_id=access_key,aws_secret_access_key=secret_access_key)
files=['sports.json','news.json','gaming.json','food.json','coding.json','animals.json']
folder_name='jsonfiles/'
my_bucket='youtubedatafile'
for i in files:   
    key_name=folder_name+i
    try:
        s3_client.upload_file(Filename=i,Bucket=my_bucket,Key=key_name)
        print("inserted successfully")
    except Exception as e:
        print("no")

# %%
import json
import pandas as pd
with open("sports.json","r") as file:
    f1=json.load(file)
sports=[]
for i in f1:
    if 'items' in i:
        sports.extend(i['items'])
sports_df=pd.json_normalize(sports)
sports_df
# Out:
#               kind                         etag           id  \
# 0    youtube#video  NQXmcaU4vuQ1xL_TC0OZUe0Wnbs  aFqPPAZcB0g
# 1    youtube#video  M58wni05z5BRxs9Vays4at1_r4Y  h7w-DAjKIW4
# 2    youtube#video  kX7XojvkAqAOmMVjC83muKJU1mc  01J6iADTaM0
# 3    youtube#video  EA4aq-E5FMtFzQZnOq_HEhLjNDk  cb6_MGRjx0o
# 4    youtube#video  z4OyD6NO08VFVAjR8g_4rsN0pzI  _1W3_keYqK0
# ..             ...                          ...          ...
# 473  youtube#video  P6xgTP-jHh32PRxemhnonz-Ll9c  CCTiSZrhgTc
# 474  youtube#video  uoMWg4IYj3PSstIxDjEXlwpiqrc  Dr_v1D_rhLQ
# 475  youtube#video  vesgxfVPDOAFoGVsUCoYmlUhc-A  oNaI9BvhcYM
# 476  youtube#video  9VQFXPSIU0JtLHGo9ng9NOUyfRI  grA9g8KFqcY
# 477  youtube#video  Ht1YMKTbwVnTbaivgxAsn9DZVH4  PW7Hoctddv8
#
#       snippet.publishedAt         snippet.channelId  \
# 0    2024-08-21T17:57:32Z  UC_WKb6N9iTGc77hxwXLDrbA
# 1    2024-08-22T01:11:43Z  UC_WKb6N9iTGc77hxwXLDrbA
# 2    2024-08-22T01:09:27Z  UC_WKb6N9iTGc77hxwXLDrbA
# 3    2024-08-17T21:45:15Z  UC_WKb6N9iTGc77hxwXLDrbA
# 4    2024-08-14T21:54:57Z  UC_WKb6N9iTGc77hxwXLDrbA
# ..                    ...                       ...
# 473  2023-08-19T16:46:17Z  UCmqfX0S3x0I3uwLkPdpX03w
# 474  2023-07-28T15:23:24Z  UCmqfX0S3x0I3uwLkPdpX03w
# 475  2023-07-31T14:54:44Z  UCmqfX0S3x0I3uwLkPdpX03w
# 476  2023-04-25T04:30:10Z  UCmqfX0S3x0I3uwLkPdpX03w
# 477  2023-04-27T06:30:52Z  UCmqfX0S3x0I3uwLkPdpX03w
#
#                                          snippet.title  \
# 0    1st Test Day 1 | Highlights | Sri Lanka Tour O...
# 1    Young Boys vs Galatasaray | Key Moments | UEFA...
# 2    Dynamo Kyiv vs FC Salzburg | Key Moments | UEF...
# 3    Bayer Leverkusen vs VfB Stuttgart | Final | Hi...
# 4    Real Madrid vs Atalanta | Final | Highlights |...
# ..                                                 ...
# 473  FIFA Women's World Cup | Spain 🇪🇸 vs England 🏴...
# 474  Premier League | Sergio Agüero's Debut & Journ...
# 475     Premier League | Henderson's Glorious Farewell
# 476  IPL 2023 | Irfan and Yusuf Pathan make their d...
# 477  IPL 2023 | Fun With The Pathans | Cheeky Singl...
#
#                                    snippet.description  \
# 0    England and Sri Lanka faced each other for the...
# 1    Young Boys and Galatasaray faced each other in...
# 2    Dynamo Kyiv and FC Salzburg faced each other i...
# 3    Bayer Leverkusen and VfB Stuttgart faced each ...
# 4    Real Madrid and Atalanta faced each other in t...
# ..                                                 ...
# 473  Tune-in to the Final in #FIFAWWCOnStar, Aug 20...
# 474  "Balotelli, Agueroooooo" is etched into #PL hi...
# 475  We bid an emotional goodbye to the legendary @...
# 476  #TanmayBhat #RoshanJoshi #VarunThakur and the ...
# 477
#
#                      snippet.thumbnails.default.url  \
# 0    https://i.ytimg.com/vi/aFqPPAZcB0g/default.jpg
# 1    https://i.ytimg.com/vi/h7w-DAjKIW4/default.jpg
# 2    https://i.ytimg.com/vi/01J6iADTaM0/default.jpg
# 3    https://i.ytimg.com/vi/cb6_MGRjx0o/default.jpg
# 4    https://i.ytimg.com/vi/_1W3_keYqK0/default.jpg
# ..                                              ...
# 473  https://i.ytimg.com/vi/CCTiSZrhgTc/default.jpg
# 474  https://i.ytimg.com/vi/Dr_v1D_rhLQ/default.jpg
# 475  https://i.ytimg.com/vi/oNaI9BvhcYM/default.jpg
# 476  https://i.ytimg.com/vi/grA9g8KFqcY/default.jpg
# 477  https://i.ytimg.com/vi/PW7Hoctddv8/default.jpg
#
#      snippet.thumbnails.default.width  snippet.thumbnails.default.height  ...  \
# 0                                 120                                 90  ...
# 1                                 120                                 90  ...
# 2                                 120                                 90  ...
# 3                                 120                                 90  ...
# 4                                 120                                 90  ...
# ..                                ...                                ...  ...
# 473                               120                                 90  ...
# 474                               120                                 90  ...
# 475                               120                                 90  ...
# 476                               120                                 90  ...
# 477                               120                                 90  ...
#
#     contentDetails.caption  contentDetails.licensedContent  \
# 0                    false                            True
# 1                    false                            True
# 2                    false                            True
# 3                    false                            True
# 4                    false                            True
# ..                     ...                             ...
# 473                  false                            True
# 474                  false                            True
# 475                  false                            True
# 476                  false                            True
# 477                  false                           False
#
#      contentDetails.regionRestriction.allowed contentDetails.projection  \
# 0        [AF, BD, BT, IN, LK, MM, MV, NP, PK]               rectangular
# 1            [AF, BD, BT, IN, LK, MV, NP, PK]               rectangular
# 2            [AF, BD, BT, IN, LK, MV, NP, PK]               rectangular
# 3                [BD, BT, IN, LK, MV, NP, PK]               rectangular
# 4        [AF, BD, BT, IN, LK, MM, MV, NP, PK]               rectangular
# ..                                        ...                       ...
# 473                                      [IN]               rectangular
# 474                                      [IN]               rectangular
# 475                                      [IN]               rectangular
# 476                                      [IN]               rectangular
# 477                                       NaN               rectangular
#
#      statistics.viewCount  statistics.likeCount statistics.favoriteCount  \
# 0                   77053                  2486                        0
# 1                     788                    32                        0
# 2                     184                     6                        0
# 3                    9472                   346                        0
# 4                  154382                  3837                        0
# ..                    ...                   ...                      ...
# 473                  2303                    39                        0
# 474                  2954                   100                        0
# 475                  2087                    62                        0
# 476                137654                  5812                        0
# 477                358900                 14189                        0
#
#      statistics.commentCount  contentDetails.regionRestriction.blocked  \
# 0                         24                                       NaN
# 1                          2                                       NaN
# 2                          0                                       NaN
# 3                         10                                       NaN
# 4                         48                                       NaN
# ..                       ...                                       ...
# 473                        2                                       NaN
# 474                        0                                       NaN
# 475                        2                                       NaN
# 476                       66                                       NaN
# 477                       30                                       NaN
#
#     snippet.defaultLanguage
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ..                      ...
# 473                     NaN
# 474                     NaN
# 475                     NaN
# 476                     NaN
# 477                     NaN
#
# [478 rows x 42 columns]

# %%
with open("news.json","r") as file:
    f2=json.load(file)
news=[]
for i in f2:
    if 'items' in i:
        news.extend(i['items'])
news_df=pd.json_normalize(news)
news_df
# Out:
#               kind                         etag           id  \
# 0    youtube#video  -8W9Z1XmciIUTjgbhJWJj8o-2TU  ZBbZP8Ar_yI
# 1    youtube#video  XjPbjuKw_YjDiUmw7eufMEb9Irc  xGnJ66kgftw
# 2    youtube#video  r4Gp8Ow8BCYnG7ZaK0lgA-JSV7Q  meJu_Agp4dU
# 3    youtube#video  8QzbL2ghBPGo8PNUj2peSFTiPAg  rTkrpsublFs
# 4    youtube#video  TtZrRoComUSFuj0S2tOQelZFUyA  0BbCk1dYMV0
# ..             ...                          ...          ...
# 482  youtube#video  W3wCmyJp0SvgJYpwpe_Kewevb30  -WT4AG3xe30
# 483  youtube#video  799Wc9rwPjIUEK4KrlaUsG9l5eU  ghTvqXkQma8
# 484  youtube#video  5GrckkENDVGYrf1F0umGdUbeAiY  8xm6r4QvQ8g
# 485  youtube#video  w4frLdrvTu220t9t9UYhuw4KIDo  39kAu-Ad-9Y
# 486  youtube#video  MIk_hn408CayJWWfq-Ctb7BtzGU  JxinsUroKyY
#
#       snippet.publishedAt         snippet.channelId  \
# 0    2024-08-22T01:26:37Z  UCYPvAwZP8pZhSMW8qs7cVCw
# 1    2024-08-21T23:31:06Z  UCYPvAwZP8pZhSMW8qs7cVCw
# 2    2024-08-16T16:52:13Z  UCYPvAwZP8pZhSMW8qs7cVCw
# 3    2024-08-16T18:52:23Z  UCYPvAwZP8pZhSMW8qs7cVCw
# 4    2024-08-16T13:04:46Z  UCYPvAwZP8pZhSMW8qs7cVCw
# ..                    ...                       ...
# 482  2024-06-26T13:00:00Z  UCJEDFSxHHOW1PpBccdSxOTA
# 483  2023-12-28T07:45:02Z  UCJEDFSxHHOW1PpBccdSxOTA
# 484  2023-12-22T10:08:31Z  UCJEDFSxHHOW1PpBccdSxOTA
# 485  2023-09-06T15:30:09Z  UCJEDFSxHHOW1PpBccdSxOTA
# 486  2023-08-17T14:00:25Z  UCJEDFSxHHOW1PpBccdSxOTA
#
#                                          snippet.title  \
# 0    LIVE UPDATES: Badlapur Boils Over Sex Assault ...
# 1    Another Rape Horror Shocks India: NHRC Issues ...
# 2    India First With Gaurav Sawant LIVE: EC Sounds...
# 3    LIVE: Haryana Assembly Polls 2024 Date | Elect...
# 4    LIVE: Beating Retreat Ceremony | Attari-Wagah ...
# ..                                                 ...
# 482  Arvind Kejriwal Arrest: AAP's Jasmine Shah Acc...
# 483  Wrestlers Protest: Sanjay Singh Takes A Jibe A...
# 484  "An Irreparable Loss"; Sakshi Malik's Mother V...
# 485  India vs Bharat Explained: Sanatan Dharm | One...
# 486  World Cup Squad 2023 India: Can India Win The ...
#
#                                    snippet.description  \
# 0    LIVE UPDATES: Badlapur Boils Over Sex Assault ...
# 1    Another Rape Horror Shocks India: NHRC Issues ...
# 2    India First With Gaurav Sawant LIVE: EC Sounds...
# 3    LIVE: Haryana Assembly Polls 2024 Date | Elect...
# 4    LIVE: Beating Retreat Ceremony | Attari-Wagah ...
# ..                                                 ...
# 482  Arvind Kejriwal Arrest: AAP leader Jasmine Sha...
# 483  Wrestlers Protest: Suspended Wrestling Federat...
# 484  Sudesh Malik, the mother of Olympic medalist w...
# 485  India Name Change: Barely two weeks before Par...
# 486  ICC World Cup 2023: In this episode of #HarshT...
#
#                         snippet.thumbnails.default.url  \
# 0       https://i.ytimg.com/vi/ZBbZP8Ar_yI/default.jpg
# 1    https://i.ytimg.com/vi/xGnJ66kgftw/default_liv...
# 2       https://i.ytimg.com/vi/meJu_Agp4dU/default.jpg
# 3       https://i.ytimg.com/vi/rTkrpsublFs/default.jpg
# 4       https://i.ytimg.com/vi/0BbCk1dYMV0/default.jpg
# ..                                                 ...
# 482     https://i.ytimg.com/vi/-WT4AG3xe30/default.jpg
# 483     https://i.ytimg.com/vi/ghTvqXkQma8/default.jpg
# 484     https://i.ytimg.com/vi/8xm6r4QvQ8g/default.jpg
# 485     https://i.ytimg.com/vi/39kAu-Ad-9Y/default.jpg
# 486     https://i.ytimg.com/vi/JxinsUroKyY/default.jpg
#
#      snippet.thumbnails.default.width  snippet.thumbnails.default.height  ...  \
# 0                                 120                                 90  ...
# 1                                 120                                 90  ...
# 2                                 120                                 90  ...
# 3                                 120                                 90  ...
# 4                                 120                                 90  ...
# ..                                ...                                ...  ...
# 482                               120                                 90  ...
# 483                               120                                 90  ...
# 484                               120                                 90  ...
# 485                               120                                 90  ...
# 486                               120                                 90  ...
#
#     contentDetails.caption  contentDetails.licensedContent  \
# 0                    false                            True
# 1                    false                            True
# 2                    false                            True
# 3                    false                           False
# 4                    false                            True
# ..                     ...                             ...
# 482                  false                            True
# 483                  false                            True
# 484                  false                            True
# 485                  false                            True
# 486                  false                            True
#
#      contentDetails.contentRating.ytRating contentDetails.projection  \
# 0                          ytAgeRestricted               rectangular
# 1                                      NaN               rectangular
# 2                                      NaN               rectangular
# 3                                      NaN               rectangular
# 4                                      NaN               rectangular
# ..                                     ...                       ...
# 482                                    NaN               rectangular
# 483                                    NaN               rectangular
# 484                                    NaN               rectangular
# 485                                    NaN               rectangular
# 486                                    NaN               rectangular
#
#      statistics.viewCount  statistics.likeCount statistics.favoriteCount  \
# 0                    1458                     7                        0
# 1                    6731                    20                        0
# 2                    1291                     6                        0
# 3                   51478                   137                        0
# 4                    3383                    36                        0
# ..                    ...                   ...                      ...
# 482                  4868                    71                        0
# 483                  2611                    13                        0
# 484                  2032                    58                        0
# 485                  3650                    48                        0
# 486                  1541                    18                        0
#
#      statistics.commentCount  contentDetails.regionRestriction.blocked  \
# 0                          0                                       NaN
# 1                          0                                       NaN
# 2                          0                                       NaN
# 3                          7                                       NaN
# 4                          0                                       NaN
# ..                       ...                                       ...
# 482                       32                                       NaN
# 483                        4                                       NaN
# 484                       14                                       NaN
# 485                        5                                       NaN
# 486                        7                                       NaN
#
#     snippet.defaultLanguage
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ..                      ...
# 482                      en
# 483                      en
# 484                      en
# 485                      en
# 486                      en
#
# [487 rows x 42 columns]

# %%
with open("gaming.json") as file:
    f3=json.load(file)
gaming=[]
for i in f3:
    if 'items' in i:
        gaming.extend(i['items'])
gaming_df=pd.json_normalize(gaming)
gaming_df
# Out:
#               kind                         etag           id  \
# 0    youtube#video  DZbrLMewSoppG8MINyy_Ip3edTI  4WF-58T_zQM
# 1    youtube#video  -W4DGpLPJtwIlnTumLbqMUA8aSY  vcrNUx9Ip3g
# 2    youtube#video  U5UYh6_8Y-mvxG8kvyMVHj7Er70  RN-cUIKVzoc
# 3    youtube#video  DjUaepSWlMBpHCilgqOgrPlcfqw  uaPt4FYwmQ0
# 4    youtube#video  RMYIMwipaBGf70cnYrrIobmM3bI  QSidy63qhQE
# ..             ...                          ...          ...
# 169  youtube#video  sYxWlRE7X0PmLxh3XbiXwGjkTuw  pgGxT9ydaN8
# 170  youtube#video  sjRPt0zx8xSh0E05nNrSo9yIhV0  rPAxJtNQQkY
# 171  youtube#video  4yqRWBWkI64WsMXyimrc67cvsYg  aryrtuFreRE
# 172  youtube#video  Nx3h7atfTiazXz57SQ7AF-tqq2I  H6v7Q7VRwq0
# 173  youtube#video  e9BAtTOvdSnbigZrYhNZj_GhkrM  T6A_p_ztKAk
#
#       snippet.publishedAt         snippet.channelId  \
# 0    2024-05-01T08:00:02Z  UC85aYbNSFjsJdxfpxgQr8tA
# 1    2024-05-03T08:00:36Z  UC85aYbNSFjsJdxfpxgQr8tA
# 2    2023-12-06T15:00:31Z  UC85aYbNSFjsJdxfpxgQr8tA
# 3    2023-12-07T13:00:43Z  UC85aYbNSFjsJdxfpxgQr8tA
# 4    2023-05-12T12:00:18Z  UC85aYbNSFjsJdxfpxgQr8tA
# ..                    ...                       ...
# 169  2016-08-30T00:01:12Z  UC9YydG57epLqxA9cTzZXSeQ
# 170  2016-07-26T01:03:07Z  UC9YydG57epLqxA9cTzZXSeQ
# 171  2016-07-25T19:25:30Z  UC9YydG57epLqxA9cTzZXSeQ
# 172  2016-08-31T20:25:49Z  UC9YydG57epLqxA9cTzZXSeQ
# 173  2016-08-24T23:50:04Z  UC9YydG57epLqxA9cTzZXSeQ
#
#                                          snippet.title  \
# 0    Easily 3 Star Payback Time - Haaland Challenge...
# 1    Easily 3 Star Kicker Kick-off - Haaland Challe...
# 2         New Update - Town Hall 16 in Clash of Clans!
# 3               New Merged Defenses in Clash of Clans!
# 4    New Hero and Troop Abilities Explained (Clash ...
# ..                                                 ...
# 169  CWL - PS4 Top 5 Plays of the Year [Capture the...
# 170  Stage 2 FINALS: CWL esports Report - Call of D...
# 171  Week 12 Stage 2: CWL esports Report - Call of ...
# 172  Profile Highlights: Fariko Impact Lookback - C...
# 173  Profile Highlights: XP Pioneers - Call of Duty...
#
#                                    snippet.description  \
# 0    How to 3 Star Haaland Challenge 1, Payback Tim...
# 1    How to 3 Star Haaland Challenge 1, Kicker kick...
# 2    TH16 Update Sneak Peek for Clash of Clans! Jud...
# 3    The Ricochet Cannon and Multi-Archer Tower are...
# 4    The Battle Copter is the New Hero in Builder B...
# ..                                                 ...
# 169  Capture the Flag is all about teamwork. Some o...
# 170  Take a look back at the Stage 2 FINALS of the ...
# 171  Take a look back at the Week 12 of Stage 2 of ...
# 172  In its inaugural year, Call of Duty Championsh...
# 173  Call of Duty XP is fast approaching. Mr. X sit...
#
#                      snippet.thumbnails.default.url  \
# 0    https://i.ytimg.com/vi/4WF-58T_zQM/default.jpg
# 1    https://i.ytimg.com/vi/vcrNUx9Ip3g/default.jpg
# 2    https://i.ytimg.com/vi/RN-cUIKVzoc/default.jpg
# 3    https://i.ytimg.com/vi/uaPt4FYwmQ0/default.jpg
# 4    https://i.ytimg.com/vi/QSidy63qhQE/default.jpg
# ..                                              ...
# 169  https://i.ytimg.com/vi/pgGxT9ydaN8/default.jpg
# 170  https://i.ytimg.com/vi/rPAxJtNQQkY/default.jpg
# 171  https://i.ytimg.com/vi/aryrtuFreRE/default.jpg
# 172  https://i.ytimg.com/vi/H6v7Q7VRwq0/default.jpg
# 173  https://i.ytimg.com/vi/T6A_p_ztKAk/default.jpg
#
#      snippet.thumbnails.default.width  snippet.thumbnails.default.height  ...  \
# 0                                 120                                 90  ...
# 1                                 120                                 90  ...
# 2                                 120                                 90  ...
# 3                                 120                                 90  ...
# 4                                 120                                 90  ...
# ..                                ...                                ...  ...
# 169                               120                                 90  ...
# 170                               120                                 90  ...
# 171                               120                                 90  ...
# 172                               120                                 90  ...
# 173                               120                                 90  ...
#
#     contentDetails.definition  contentDetails.caption  \
# 0                          hd                   false
# 1                          hd                   false
# 2                          hd                   false
# 3                          hd                   false
# 4                          hd                   false
# ..                        ...                     ...
# 169                        hd                   false
# 170                        hd                   false
# 171                        hd                   false
# 172                        hd                   false
# 173                        hd                   false
#
#      contentDetails.licensedContent contentDetails.projection  \
# 0                              True               rectangular
# 1                              True               rectangular
# 2                              True               rectangular
# 3                              True               rectangular
# 4                              True               rectangular
# ..                              ...                       ...
# 169                            True               rectangular
# 170                            True               rectangular
# 171                            True               rectangular
# 172                            True               rectangular
# 173                            True               rectangular
#
#      statistics.viewCount  statistics.likeCount statistics.favoriteCount  \
# 0                 1037624                 26332                        0
# 1                  520796                 14563                        0
# 2                 2182621                 75010                        0
# 3                 1434490                 55331                        0
# 4                 1179211                 39145                        0
# ..                    ...                   ...                      ...
# 169                122426                  4342                        0
# 170                 22246                   347                        0
# 171                 12432                   323                        0
# 172                 62256                  1946                        0
# 173                 61487                  2338                        0
#
#      statistics.commentCount  snippet.defaultLanguage  \
# 0                       1079                      NaN
# 1                        354                      NaN
# 2                       3748                      NaN
# 3                       1977                      NaN
# 4                       1167                      NaN
# ..                       ...                      ...
# 169                      211                      NaN
# 170                       37                      NaN
# 171                       12                      NaN
# 172                      132                      NaN
# 173                      259                      NaN
#
#     contentDetails.contentRating.ytRating
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 169                                   NaN
# 170                                   NaN
# 171                                   NaN
# 172                                   NaN
# 173                                   NaN
#
# [174 rows x 41 columns]

# %%
with open("food.json","r") as file:
    f4=json.load(file)
food=[]
for i in f4:
    if 'items' in i:
        food.extend(i['items'])
food_df=pd.json_normalize(food)
food_df
# Out:
#               kind                         etag           id  \
# 0    youtube#video  J_nJAV1GEu3LtA4UpPWfop-bFNc  JnAJXuSXBqk
# 1    youtube#video  1ZyUAcJcDVA_KPEJ8vIAciU6ei8  u5_hw6AJV-M
# 2    youtube#video  RENId_VpG6qIKvM9wacNTqMNwf0  pYyNX6j_cMI
# 3    youtube#video  lOMK5xgVi05WXriRI8zeSC3jyCo  utA56qT_Jhc
# 4    youtube#video  39so_a0BMFc67pjU_bpA_K0UBLo  abHKnPxPXPE
# ..             ...                          ...          ...
# 318  youtube#video  WyPN2k18DaRm5FjQ1tzTYxsES0I  hY-rU-pj_4g
# 319  youtube#video  3xM3P28be2b0qQABirXiw92qrOQ  Hwv7KYzjX78
# 320  youtube#video  BZgmtaoCuwU_Uwcgtpok72oolwg  aXQ0N_ofG-U
# 321  youtube#video  hzMnqiGFuQBVCKBN0oPNeQp-TIc  bTPvMdhDr2c
# 322  youtube#video  Fa3_7NjFFjfNqmKNOHl8_KD1g-g  XhkQelZX2c8
#
#       snippet.publishedAt         snippet.channelId  \
# 0    2024-04-17T03:54:52Z  UCiAq_SU0ED1C6vWFMnw8Ekg
# 1    2024-04-21T16:13:33Z  UCiAq_SU0ED1C6vWFMnw8Ekg
# 2    2022-08-28T18:52:24Z  UCiAq_SU0ED1C6vWFMnw8Ekg
# 3    2022-10-06T13:59:58Z  UCiAq_SU0ED1C6vWFMnw8Ekg
# 4    2022-04-10T15:39:52Z  UCiAq_SU0ED1C6vWFMnw8Ekg
# ..                    ...                       ...
# 318  2020-06-03T13:00:23Z  UCyEd6QBSgat5kkC6svyjudA
# 319  2020-04-05T13:00:05Z  UCyEd6QBSgat5kkC6svyjudA
# 320  2020-04-08T13:00:00Z  UCyEd6QBSgat5kkC6svyjudA
# 321  2020-02-26T13:00:08Z  UCyEd6QBSgat5kkC6svyjudA
# 322  2020-03-01T13:00:05Z  UCyEd6QBSgat5kkC6svyjudA
#
#                                          snippet.title  \
# 0    What Happened to Food Ranger?? This is what I'...
# 1               I moved to the Chinese Village (DEEP!)
# 2    Most EXTREME Street Food in Italy - The ULTIMA...
# 3    Street Food in Italy - The ULTIMATE Pasta and ...
# 4    Most UNIQUE Street Food in Saudi Arabia - RARE...
# ..                                                 ...
# 318  Indian Street Food 🇮🇳 !! Spicy Kerala Fish Cur...
# 319  Jamaican Street Food in Kingston!! 🦀SPICY CRAB...
# 320  Jamaican Food!! 🇯🇲 KING OF CURRY GOAT + Oxtail...
# 321  15 Courses BUSINESS CLASS Food on IRAN AIRLINE...
# 322  Street Food in Iran!! UNSEEN IRANIAN FOOD + Ma...
#
#                                    snippet.description  \
# 0    In this video I'm sharing with you a new idea ...
# 1    In this video I'm giving you a house tour of m...
# 2    My new blog: https://travelsecurely.com\nCHECK...
# 3    My new blog: https://travelsecurely.com\nCHECK...
# 4    My new blog: https://travelsecurely.com\nGet r...
# ..                                                 ...
# 318  🎥Spicy Indian Food in Kerala: https://youtu.be...
# 319  🔔SUBSCRIBE: http://bit.ly/MarkWiensSubscribe D...
# 320  🙏Thanks to Matt Robinson: https://www.instagra...
# 321  😃Follow Mr. Taster: https://www.youtube.com/us...
# 322  😃Follow Mr. Taster: https://www.youtube.com/us...
#
#                      snippet.thumbnails.default.url  \
# 0    https://i.ytimg.com/vi/JnAJXuSXBqk/default.jpg
# 1    https://i.ytimg.com/vi/u5_hw6AJV-M/default.jpg
# 2    https://i.ytimg.com/vi/pYyNX6j_cMI/default.jpg
# 3    https://i.ytimg.com/vi/utA56qT_Jhc/default.jpg
# 4    https://i.ytimg.com/vi/abHKnPxPXPE/default.jpg
# ..                                              ...
# 318  https://i.ytimg.com/vi/hY-rU-pj_4g/default.jpg
# 319  https://i.ytimg.com/vi/Hwv7KYzjX78/default.jpg
# 320  https://i.ytimg.com/vi/aXQ0N_ofG-U/default.jpg
# 321  https://i.ytimg.com/vi/bTPvMdhDr2c/default.jpg
# 322  https://i.ytimg.com/vi/XhkQelZX2c8/default.jpg
#
#      snippet.thumbnails.default.width  snippet.thumbnails.default.height  ...  \
# 0                                 120                                 90  ...
# 1                                 120                                 90  ...
# 2                                 120                                 90  ...
# 3                                 120                                 90  ...
# 4                                 120                                 90  ...
# ..                                ...                                ...  ...
# 318                               120                                 90  ...
# 319                               120                                 90  ...
# 320                               120                                 90  ...
# 321                               120                                 90  ...
# 322                               120                                 90  ...
#
#     contentDetails.definition  contentDetails.caption  \
# 0                          hd                   false
# 1                          hd                    true
# 2                          hd                    true
# 3                          hd                    true
# 4                          hd                    true
# ..                        ...                     ...
# 318                        hd                    true
# 319                        hd                    true
# 320                        hd                    true
# 321                        hd                    true
# 322                        hd                    true
#
#      contentDetails.licensedContent contentDetails.projection  \
# 0                              True               rectangular
# 1                              True               rectangular
# 2                              True               rectangular
# 3                              True               rectangular
# 4                              True               rectangular
# ..                              ...                       ...
# 318                            True               rectangular
# 319                            True               rectangular
# 320                            True               rectangular
# 321                            True               rectangular
# 322                            True               rectangular
#
#      statistics.viewCount  statistics.likeCount statistics.favoriteCount  \
# 0                  292690                  9535                        0
# 1                  266537                  9076                        0
# 2                 1305042                 20218                        0
# 3                  614998                 11548                        0
# 4                 1551648                 21842                        0
# ..                    ...                   ...                      ...
# 318               2295519                 58721                        0
# 319               6290601                 89263                        0
# 320               8227273                127877                        0
# 321               5160205                 89330                        0
# 322               2621119                 33314                        0
#
#      statistics.commentCount  contentDetails.regionRestriction.allowed  \
# 0                       1195                                       NaN
# 1                       1039                                       NaN
# 2                        879                                       NaN
# 3                        469                                       NaN
# 4                       1072                                       NaN
# ..                       ...                                       ...
# 318                     4567                                       NaN
# 319                     8741                                       NaN
# 320                    12351                                       NaN
# 321                     8673                                       NaN
# 322                     3343                                       NaN
#
#     contentDetails.regionRestriction.blocked
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 318                                      NaN
# 319                                      NaN
# 320                                      NaN
# 321                                      NaN
# 322                                      NaN
#
# [323 rows x 42 columns]

# %%
with open("coding.json","r") as file:
    f5=json.load(file)
coding=[]
for i in f5:
    if 'items' in i:
        coding.extend(i['items'])
coding_df=pd.json_normalize(coding)
coding_df
# Out:
#               kind                         etag           id  \
# 0    youtube#video  Eb0zWSmjx6DXZSG6dM3UoQp1u5o  tH72niGTY18
# 1    youtube#video  G2URA9zVHl1TQj0oLzL_YcmSy8A  6L7fUPHHFFo
# 2    youtube#video  x4SRmZg33d02SEjz2W1C-3qOMrU  Lz3m4BI1EfY
# 3    youtube#video  NCPmMfjW7qgjJ_PwzBWep6zV0gY  hhZtiytNaBQ
# 4    youtube#video  x4SRmZg33d02SEjz2W1C-3qOMrU  Lz3m4BI1EfY
# ..             ...                          ...          ...
# 217  youtube#video  V6Vnp9XQgreuTYrbZ8EnIZ_gPI8  UPO-9iMjBpc
# 218  youtube#video  6wWCR5oxvFS0EJ67xzx3-zfZPfk  qli-JCrSwuk
# 219  youtube#video  rOVPBFSASd1z4wocnYB95jsnCtM  5o-kdjv7FD0
# 220  youtube#video  4ol08FR9JQsKwuo3kcSfypXDqBM  vYquumk4nWw
# 221  youtube#video  mY1lU_tarNBQg40Ct9Lu085Uddg  xOlhR_2QCXY
#
#       snippet.publishedAt         snippet.channelId  \
# 0    2022-02-01T07:42:45Z  UCqrILQNl5Ed9Dz6CGMyvMTQ
# 1    2022-03-08T01:07:32Z  UCqrILQNl5Ed9Dz6CGMyvMTQ
# 2    2021-12-11T02:41:21Z  UCqrILQNl5Ed9Dz6CGMyvMTQ
# 3    2021-12-12T04:48:13Z  UCqrILQNl5Ed9Dz6CGMyvMTQ
# 4    2021-12-11T02:41:21Z  UCqrILQNl5Ed9Dz6CGMyvMTQ
# ..                    ...                       ...
# 217  2017-11-02T00:38:19Z  UCxX9wt5FWQUAAz4UrysqK9A
# 218  2018-07-14T05:19:41Z  UCxX9wt5FWQUAAz4UrysqK9A
# 219  2018-05-26T01:23:27Z  UCxX9wt5FWQUAAz4UrysqK9A
# 220  2017-12-14T01:59:53Z  UCxX9wt5FWQUAAz4UrysqK9A
# 221  2016-03-13T02:58:15Z  UCxX9wt5FWQUAAz4UrysqK9A
#
#                                          snippet.title  \
# 0               Highest Paying Blockchain Jobs in 2022
# 1    Top Skills to Learn as a Blockchain Developer ...
# 2    Your Roadmap to becoming a Frontend + Web 3.0 ...
# 3    🔴 Build Modern Cryptopunk Clone with React.js ...
# 4    Your Roadmap to becoming a Frontend + Web 3.0 ...
# ..                                                 ...
# 217  How I Got a Job at Google as a Software Engine...
# 218  Facebook Coding Interview Question - How Many ...
# 219  Amazon Coding Interview Question - Recursive S...
# 220      What Is Dynamic Programming and How To Use It
# 221         0-1 Knapsack Problem (Dynamic Programming)
#
#                                    snippet.description  \
# 0    Highest Paying Blockchain Jobs in 2022 🤑#block...
# 1    Sign up for our talent pool 👉 https://airtable...
# 2    Register for the challenge 👉 https://www.cleve...
# 3    Wanna be part of the Discord Community? Regist...
# 4    Register for the challenge 👉 https://www.cleve...
# ..                                                 ...
# 217  How to get a job at Google: Here are the 6 ste...
# 218  Facebook coding interview question and answer ...
# 219  Amazon coding interview question and answer - ...
# 220  **Dynamic Programming Tutorial**\nThis is a qu...
# 221  Dynamic Programming Tutorial with 0-1 Knapsack...
#
#                      snippet.thumbnails.default.url  \
# 0    https://i.ytimg.com/vi/tH72niGTY18/default.jpg
# 1    https://i.ytimg.com/vi/6L7fUPHHFFo/default.jpg
# 2    https://i.ytimg.com/vi/Lz3m4BI1EfY/default.jpg
# 3    https://i.ytimg.com/vi/hhZtiytNaBQ/default.jpg
# 4    https://i.ytimg.com/vi/Lz3m4BI1EfY/default.jpg
# ..                                              ...
# 217  https://i.ytimg.com/vi/UPO-9iMjBpc/default.jpg
# 218  https://i.ytimg.com/vi/qli-JCrSwuk/default.jpg
# 219  https://i.ytimg.com/vi/5o-kdjv7FD0/default.jpg
# 220  https://i.ytimg.com/vi/vYquumk4nWw/default.jpg
# 221  https://i.ytimg.com/vi/xOlhR_2QCXY/default.jpg
#
#      snippet.thumbnails.default.width  snippet.thumbnails.default.height  ...  \
# 0                                 120                                 90  ...
# 1                                 120                                 90  ...
# 2                                 120                                 90  ...
# 3                                 120                                 90  ...
# 4                                 120                                 90  ...
# ..                                ...                                ...  ...
# 217                               120                                 90  ...
# 218                               120                                 90  ...
# 219                               120                                 90  ...
# 220                               120                                 90  ...
# 221                               120                                 90  ...
#
#     statistics.favoriteCount  statistics.commentCount  \
# 0                          0                      103
# 1                          0                       18
# 2                          0                      216
# 3                          0                      289
# 4                          0                      216
# ..                       ...                      ...
# 217                        0                     1800
# 218                        0                      544
# 219                        0                     1391
# 220                        0                     1617
# 221                        0                      252
#
#                       snippet.thumbnails.standard.url  \
# 0                                                 NaN
# 1    https://i.ytimg.com/vi/6L7fUPHHFFo/sddefault.jpg
# 2    https://i.ytimg.com/vi/Lz3m4BI1EfY/sddefault.jpg
# 3    https://i.ytimg.com/vi/hhZtiytNaBQ/sddefault.jpg
# 4    https://i.ytimg.com/vi/Lz3m4BI1EfY/sddefault.jpg
# ..                                                ...
# 217  https://i.ytimg.com/vi/UPO-9iMjBpc/sddefault.jpg
# 218  https://i.ytimg.com/vi/qli-JCrSwuk/sddefault.jpg
# 219  https://i.ytimg.com/vi/5o-kdjv7FD0/sddefault.jpg
# 220  https://i.ytimg.com/vi/vYquumk4nWw/sddefault.jpg
# 221  https://i.ytimg.com/vi/xOlhR_2QCXY/sddefault.jpg
#
#     snippet.thumbnails.standard.width  snippet.thumbnails.standard.height  \
# 0                                 NaN                                 NaN
# 1                               640.0                               480.0
# 2                               640.0                               480.0
# 3                               640.0                               480.0
# 4                               640.0                               480.0
# ..                                ...                                 ...
# 217                             640.0                               480.0
# 218                             640.0                               480.0
# 219                             640.0                               480.0
# 220                             640.0                               480.0
# 221                             640.0                               480.0
#
#                          snippet.thumbnails.maxres.url  \
# 0                                                  NaN
# 1    https://i.ytimg.com/vi/6L7fUPHHFFo/maxresdefau...
# 2    https://i.ytimg.com/vi/Lz3m4BI1EfY/maxresdefau...
# 3    https://i.ytimg.com/vi/hhZtiytNaBQ/maxresdefau...
# 4    https://i.ytimg.com/vi/Lz3m4BI1EfY/maxresdefau...
# ..                                                 ...
# 217  https://i.ytimg.com/vi/UPO-9iMjBpc/maxresdefau...
# 218  https://i.ytimg.com/vi/qli-JCrSwuk/maxresdefau...
# 219  https://i.ytimg.com/vi/5o-kdjv7FD0/maxresdefau...
# 220  https://i.ytimg.com/vi/vYquumk4nWw/maxresdefau...
# 221                                                NaN
#
#     snippet.thumbnails.maxres.width snippet.thumbnails.maxres.height  \
# 0                               NaN                              NaN
# 1                            1280.0                            720.0
# 2                            1280.0                            720.0
# 3                            1280.0                            720.0
# 4                            1280.0                            720.0
# ..                              ...                              ...
# 217                          1280.0                            720.0
# 218                          1280.0                            720.0
# 219                          1280.0                            720.0
# 220                          1280.0                            720.0
# 221                             NaN                              NaN
#
#     contentDetails.regionRestriction.blocked  \
# 0                                        NaN
# 1                                       [RU]
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 217                                      NaN
# 218                                      NaN
# 219                                      NaN
# 220                                      NaN
# 221                                      NaN
#
#     contentDetails.regionRestriction.allowed
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 217                                      NaN
# 218                                      NaN
# 219                                      NaN
# 220                                      NaN
# 221                                      NaN
#
# [222 rows x 42 columns]

# %%
with open("animals.json","r") as file:
    f5=json.load(file)
animals=[]
for i in f5:
    if 'items' in i:
        animals.extend(i['items'])
animals_df=pd.json_normalize(animals)
animals_df
# Out:
#               kind                         etag           id  \
# 0    youtube#video  itixghz9jJvGQUN_6r_8wREXoW8  RnOIIDnRJ50
# 1    youtube#video  TjRH3sQzn-ComZ6vBt1mS2j_pb4  gv7fG3YE7cc
# 2    youtube#video  igBSOZevhvNHxTTexNRQpRyrOBA  4QieIjCSsqc
# 3    youtube#video  OlRux-q7nMPlqHbbQVNtsM-9jc4  SYvhpZ9K8IQ
# 4    youtube#video  m7PHUCWMJoHfP0uQJ1yZy_DNrA4  2kev31VMpAo
# ..             ...                          ...          ...
# 299  youtube#video  vf9IttvsW99fekq6TvI3EuhzTnY  7RzoNyI17M4
# 300  youtube#video  9agCcmJvIxOswponyFFiq8vol5Q  gZkcExDOQnY
# 301  youtube#video  Ej-OLWG1Y2OZU5C1aeq8zOXg1Uo  BV-6NBLVE6g
# 302  youtube#video  i_KgHGAiaJXc1LUIyYTT4B6LEcE  4oavOSGo39w
# 303  youtube#video  wKtLK0wnC24IDvJcDx2foHRumHc  9c3d8BnTxHM
#
#       snippet.publishedAt         snippet.channelId  \
# 0    2024-07-25T13:00:23Z  UCwmZiChSryoWQCZMIQezgTg
# 1    2024-07-16T15:00:42Z  UCwmZiChSryoWQCZMIQezgTg
# 2    2024-08-11T15:00:05Z  UCwmZiChSryoWQCZMIQezgTg
# 3    2024-08-04T13:00:33Z  UCwmZiChSryoWQCZMIQezgTg
# 4    2024-07-23T15:00:05Z  UCwmZiChSryoWQCZMIQezgTg
# ..                    ...                       ...
# 299  2024-08-14T11:59:55Z  UCQtW2oz8ec8pHjjxawujNjg
# 300  2023-07-02T17:00:30Z  UCz73YrQjemoqx6ZvVfJDAew
# 301  2023-07-03T04:00:06Z  UCz73YrQjemoqx6ZvVfJDAew
# 302  2020-09-09T13:59:44Z  UCz73YrQjemoqx6ZvVfJDAew
# 303  2020-09-14T17:09:38Z  UCz73YrQjemoqx6ZvVfJDAew
#
#                                          snippet.title  \
# 0    Finding Wallace's Flying Frog | Bill Bailey's ...
# 1    Bug Catching Isn't as Easy as You’d Think | Bi...
# 2    The Fastest Ant on Earth | Earth's Great Seaso...
# 3    Nubian Ibex Fight for Females | Earth's Great ...
# 4    Can These Tortoises Avoid Being Boiled In Thei...
# ..                                                 ...
# 299  The Big Blue - Ocean Stories from Down Under |...
# 300       10 Times Mongooses and Cobras Take the Stage
# 301      10 Moments When Hyenas Brutally Attack Babies
# 302  Wild Life - Lion Pride Documentary 2020 Full H...
# 303  Lion Documentary - New Generation, Will They S...
#
#                                    snippet.description  \
# 0    Spotting a Wallace's flying frog is not easy, ...
# 1    In order to study insects, they must be collec...
# 2    With extra long legs to raise their bodies abo...
# 3    In the unforgiving mountainous regions of the ...
# 4    Out in the open, extreme heat can kill these t...
# ..                                                 ...
# 299  The Big Blue - Ocean Stories from Down Under |...
# 300       10 Times Mongooses and Cobras Take the Stage
# 301      10 Moments When Hyenas Brutally Attack Babies
# 302  National Geographic Documentary about Nsefu Li...
# 303  Lionesses of Nsefu Pride are having a hard tim...
#
#                      snippet.thumbnails.default.url  \
# 0    https://i.ytimg.com/vi/RnOIIDnRJ50/default.jpg
# 1    https://i.ytimg.com/vi/gv7fG3YE7cc/default.jpg
# 2    https://i.ytimg.com/vi/4QieIjCSsqc/default.jpg
# 3    https://i.ytimg.com/vi/SYvhpZ9K8IQ/default.jpg
# 4    https://i.ytimg.com/vi/2kev31VMpAo/default.jpg
# ..                                              ...
# 299  https://i.ytimg.com/vi/7RzoNyI17M4/default.jpg
# 300  https://i.ytimg.com/vi/gZkcExDOQnY/default.jpg
# 301  https://i.ytimg.com/vi/BV-6NBLVE6g/default.jpg
# 302  https://i.ytimg.com/vi/4oavOSGo39w/default.jpg
# 303  https://i.ytimg.com/vi/9c3d8BnTxHM/default.jpg
#
#      snippet.thumbnails.default.width  snippet.thumbnails.default.height  ...  \
# 0                                 120                                 90  ...
# 1                                 120                                 90  ...
# 2                                 120                                 90  ...
# 3                                 120                                 90  ...
# 4                                 120                                 90  ...
# ..                                ...                                ...  ...
# 299                               120                                 90  ...
# 300                               120                                 90  ...
# 301                               120                                 90  ...
# 302                               120                                 90  ...
# 303                               120                                 90  ...
#
#     contentDetails.caption  contentDetails.licensedContent  \
# 0                     true                            True
# 1                     true                            True
# 2                     true                            True
# 3                     true                            True
# 4                     true                            True
# ..                     ...                             ...
# 299                  false                            True
# 300                  false                           False
# 301                  false                           False
# 302                  false                           False
# 303                  false                           False
#
#      contentDetails.projection statistics.viewCount  statistics.likeCount  \
# 0                  rectangular                28715                  1235
# 1                  rectangular                29312                   957
# 2                  rectangular                52469                  2070
# 3                  rectangular                38055                  1317
# 4                  rectangular                47538                  1931
# ..                         ...                  ...                   ...
# 299                rectangular                33153                   623
# 300                rectangular                 1122                    18
# 301                rectangular                 1361                    24
# 302                rectangular               190573                  2882
# 303                rectangular               354288                  4974
#
#      statistics.favoriteCount statistics.commentCount  \
# 0                           0                      95
# 1                           0                      28
# 2                           0                      99
# 3                           0                     113
# 4                           0                      98
# ..                        ...                     ...
# 299                         0                      24
# 300                         0                       6
# 301                         0                       5
# 302                         0                     187
# 303                         0                     340
#
#      contentDetails.regionRestriction.blocked  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 299                                  [CN, NZ]
# 300                                       NaN
# 301                                       NaN
# 302                                       NaN
# 303                                       NaN
#
#      contentDetails.regionRestriction.allowed  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 299                                       NaN
# 300                                       NaN
# 301                                       NaN
# 302                                       NaN
# 303                                       NaN
#
#     contentDetails.contentRating.ytRating
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 299                                   NaN
# 300                                   NaN
# 301                                   NaN
# 302                                   NaN
# 303                                   NaN
#
# [304 rows x 43 columns]

# %%
df=pd.concat([sports_df,news_df,gaming_df,food_df,coding_df,animals_df],ignore_index=True)
df
# Out:
#                kind                         etag           id  \
# 0     youtube#video  NQXmcaU4vuQ1xL_TC0OZUe0Wnbs  aFqPPAZcB0g
# 1     youtube#video  M58wni05z5BRxs9Vays4at1_r4Y  h7w-DAjKIW4
# 2     youtube#video  kX7XojvkAqAOmMVjC83muKJU1mc  01J6iADTaM0
# 3     youtube#video  EA4aq-E5FMtFzQZnOq_HEhLjNDk  cb6_MGRjx0o
# 4     youtube#video  z4OyD6NO08VFVAjR8g_4rsN0pzI  _1W3_keYqK0
# ...             ...                          ...          ...
# 1983  youtube#video  vf9IttvsW99fekq6TvI3EuhzTnY  7RzoNyI17M4
# 1984  youtube#video  9agCcmJvIxOswponyFFiq8vol5Q  gZkcExDOQnY
# 1985  youtube#video  Ej-OLWG1Y2OZU5C1aeq8zOXg1Uo  BV-6NBLVE6g
# 1986  youtube#video  i_KgHGAiaJXc1LUIyYTT4B6LEcE  4oavOSGo39w
# 1987  youtube#video  wKtLK0wnC24IDvJcDx2foHRumHc  9c3d8BnTxHM
#
#        snippet.publishedAt         snippet.channelId  \
# 0     2024-08-21T17:57:32Z  UC_WKb6N9iTGc77hxwXLDrbA
# 1     2024-08-22T01:11:43Z  UC_WKb6N9iTGc77hxwXLDrbA
# 2     2024-08-22T01:09:27Z  UC_WKb6N9iTGc77hxwXLDrbA
# 3     2024-08-17T21:45:15Z  UC_WKb6N9iTGc77hxwXLDrbA
# 4     2024-08-14T21:54:57Z  UC_WKb6N9iTGc77hxwXLDrbA
# ...                    ...                       ...
# 1983  2024-08-14T11:59:55Z  UCQtW2oz8ec8pHjjxawujNjg
# 1984  2023-07-02T17:00:30Z  UCz73YrQjemoqx6ZvVfJDAew
# 1985  2023-07-03T04:00:06Z  UCz73YrQjemoqx6ZvVfJDAew
# 1986  2020-09-09T13:59:44Z  UCz73YrQjemoqx6ZvVfJDAew
# 1987  2020-09-14T17:09:38Z  UCz73YrQjemoqx6ZvVfJDAew
#
#                                           snippet.title  \
# 0     1st Test Day 1 | Highlights | Sri Lanka Tour O...
# 1     Young Boys vs Galatasaray | Key Moments | UEFA...
# 2     Dynamo Kyiv vs FC Salzburg | Key Moments | UEF...
# 3     Bayer Leverkusen vs VfB Stuttgart | Final | Hi...
# 4     Real Madrid vs Atalanta | Final | Highlights |...
# ...                                                 ...
# 1983  The Big Blue - Ocean Stories from Down Under |...
# 1984       10 Times Mongooses and Cobras Take the Stage
# 1985      10 Moments When Hyenas Brutally Attack Babies
# 1986  Wild Life - Lion Pride Documentary 2020 Full H...
# 1987  Lion Documentary - New Generation, Will They S...
#
#                                     snippet.description  \
# 0     England and Sri Lanka faced each other for the...
# 1     Young Boys and Galatasaray faced each other in...
# 2     Dynamo Kyiv and FC Salzburg faced each other i...
# 3     Bayer Leverkusen and VfB Stuttgart faced each ...
# 4     Real Madrid and Atalanta faced each other in t...
# ...                                                 ...
# 1983  The Big Blue - Ocean Stories from Down Under |...
# 1984       10 Times Mongooses and Cobras Take the Stage
# 1985      10 Moments When Hyenas Brutally Attack Babies
# 1986  National Geographic Documentary about Nsefu Li...
# 1987  Lionesses of Nsefu Pride are having a hard tim...
#
#                       snippet.thumbnails.default.url  \
# 0     https://i.ytimg.com/vi/aFqPPAZcB0g/default.jpg
# 1     https://i.ytimg.com/vi/h7w-DAjKIW4/default.jpg
# 2     https://i.ytimg.com/vi/01J6iADTaM0/default.jpg
# 3     https://i.ytimg.com/vi/cb6_MGRjx0o/default.jpg
# 4     https://i.ytimg.com/vi/_1W3_keYqK0/default.jpg
# ...                                              ...
# 1983  https://i.ytimg.com/vi/7RzoNyI17M4/default.jpg
# 1984  https://i.ytimg.com/vi/gZkcExDOQnY/default.jpg
# 1985  https://i.ytimg.com/vi/BV-6NBLVE6g/default.jpg
# 1986  https://i.ytimg.com/vi/4oavOSGo39w/default.jpg
# 1987  https://i.ytimg.com/vi/9c3d8BnTxHM/default.jpg
#
#       snippet.thumbnails.default.width  snippet.thumbnails.default.height  \
# 0                                  120                                 90
# 1                                  120                                 90
# 2                                  120                                 90
# 3                                  120                                 90
# 4                                  120                                 90
# ...                                ...                                ...
# 1983                               120                                 90
# 1984                               120                                 90
# 1985                               120                                 90
# 1986                               120                                 90
# 1987                               120                                 90
#
#       ... contentDetails.licensedContent  \
# 0     ...                           True
# 1     ...                           True
# 2     ...                           True
# 3     ...                           True
# 4     ...                           True
# ...   ...                            ...
# 1983  ...                           True
# 1984  ...                          False
# 1985  ...                          False
# 1986  ...                          False
# 1987  ...                          False
#
#       contentDetails.regionRestriction.allowed  contentDetails.projection  \
# 0         [AF, BD, BT, IN, LK, MM, MV, NP, PK]                rectangular
# 1             [AF, BD, BT, IN, LK, MV, NP, PK]                rectangular
# 2             [AF, BD, BT, IN, LK, MV, NP, PK]                rectangular
# 3                 [BD, BT, IN, LK, MV, NP, PK]                rectangular
# 4         [AF, BD, BT, IN, LK, MM, MV, NP, PK]                rectangular
# ...                                        ...                        ...
# 1983                                       NaN                rectangular
# 1984                                       NaN                rectangular
# 1985                                       NaN                rectangular
# 1986                                       NaN                rectangular
# 1987                                       NaN                rectangular
#
#      statistics.viewCount  statistics.likeCount  statistics.favoriteCount  \
# 0                   77053                  2486                         0
# 1                     788                    32                         0
# 2                     184                     6                         0
# 3                    9472                   346                         0
# 4                  154382                  3837                         0
# ...                   ...                   ...                       ...
# 1983                33153                   623                         0
# 1984                 1122                    18                         0
# 1985                 1361                    24                         0
# 1986               190573                  2882                         0
# 1987               354288                  4974                         0
#
#      statistics.commentCount  contentDetails.regionRestriction.blocked  \
# 0                         24                                       NaN
# 1                          2                                       NaN
# 2                          0                                       NaN
# 3                         10                                       NaN
# 4                         48                                       NaN
# ...                      ...                                       ...
# 1983                      24                                  [CN, NZ]
# 1984                       6                                       NaN
# 1985                       5                                       NaN
# 1986                     187                                       NaN
# 1987                     340                                       NaN
#
#       snippet.defaultLanguage contentDetails.contentRating.ytRating
# 0                         NaN                                   NaN
# 1                         NaN                                   NaN
# 2                         NaN                                   NaN
# 3                         NaN                                   NaN
# 4                         NaN                                   NaN
# ...                       ...                                   ...
# 1983                      NaN                                   NaN
# 1984                      NaN                                   NaN
# 1985                      NaN                                   NaN
# 1986                      NaN                                   NaN
# 1987                      NaN                                   NaN
#
# [1988 rows x 43 columns]

# %%
delete_columns=['kind','etag','snippet.publishedAt','snippet.description','snippet.thumbnails.default.url','snippet.thumbnails.default.width','snippet.thumbnails.default.height','snippet.thumbnails.medium.width',
                'snippet.thumbnails.medium.height','snippet.thumbnails.high.url','snippet.thumbnails.high.width','snippet.thumbnails.high.height','snippet.thumbnails.standard.url',
                'snippet.thumbnails.standard.width','snippet.thumbnails.standard.height','snippet.thumbnails.maxres.url','snippet.thumbnails.maxres.width',
                'snippet.thumbnails.maxres.height','contentDetails.regionRestriction.allowed','contentDetails.projection','contentDetails.dimension',
                'contentDetails.definition','contentDetails.caption','contentDetails.licensedContent','snippet.defaultAudioLanguage',
                'snippet.categoryId','snippet.liveBroadcastContent'	,'snippet.localized.title','snippet.localized.description',
                'contentDetails.regionRestriction.blocked','snippet.defaultLanguage','contentDetails.contentRating.ytRating','statistics.favoriteCount']
for i in delete_columns:
    final_df=df.drop(columns=i)
final_df
# Out:
#                kind                         etag           id  \
# 0     youtube#video  NQXmcaU4vuQ1xL_TC0OZUe0Wnbs  aFqPPAZcB0g
# 1     youtube#video  M58wni05z5BRxs9Vays4at1_r4Y  h7w-DAjKIW4
# 2     youtube#video  kX7XojvkAqAOmMVjC83muKJU1mc  01J6iADTaM0
# 3     youtube#video  EA4aq-E5FMtFzQZnOq_HEhLjNDk  cb6_MGRjx0o
# 4     youtube#video  z4OyD6NO08VFVAjR8g_4rsN0pzI  _1W3_keYqK0
# ...             ...                          ...          ...
# 1983  youtube#video  vf9IttvsW99fekq6TvI3EuhzTnY  7RzoNyI17M4
# 1984  youtube#video  9agCcmJvIxOswponyFFiq8vol5Q  gZkcExDOQnY
# 1985  youtube#video  Ej-OLWG1Y2OZU5C1aeq8zOXg1Uo  BV-6NBLVE6g
# 1986  youtube#video  i_KgHGAiaJXc1LUIyYTT4B6LEcE  4oavOSGo39w
# 1987  youtube#video  wKtLK0wnC24IDvJcDx2foHRumHc  9c3d8BnTxHM
#
#        snippet.publishedAt         snippet.channelId  \
# 0     2024-08-21T17:57:32Z  UC_WKb6N9iTGc77hxwXLDrbA
# 1     2024-08-22T01:11:43Z  UC_WKb6N9iTGc77hxwXLDrbA
# 2     2024-08-22T01:09:27Z  UC_WKb6N9iTGc77hxwXLDrbA
# 3     2024-08-17T21:45:15Z  UC_WKb6N9iTGc77hxwXLDrbA
# 4     2024-08-14T21:54:57Z  UC_WKb6N9iTGc77hxwXLDrbA
# ...                    ...                       ...
# 1983  2024-08-14T11:59:55Z  UCQtW2oz8ec8pHjjxawujNjg
# 1984  2023-07-02T17:00:30Z  UCz73YrQjemoqx6ZvVfJDAew
# 1985  2023-07-03T04:00:06Z  UCz73YrQjemoqx6ZvVfJDAew
# 1986  2020-09-09T13:59:44Z  UCz73YrQjemoqx6ZvVfJDAew
# 1987  2020-09-14T17:09:38Z  UCz73YrQjemoqx6ZvVfJDAew
#
#                                           snippet.title  \
# 0     1st Test Day 1 | Highlights | Sri Lanka Tour O...
# 1     Young Boys vs Galatasaray | Key Moments | UEFA...
# 2     Dynamo Kyiv vs FC Salzburg | Key Moments | UEF...
# 3     Bayer Leverkusen vs VfB Stuttgart | Final | Hi...
# 4     Real Madrid vs Atalanta | Final | Highlights |...
# ...                                                 ...
# 1983  The Big Blue - Ocean Stories from Down Under |...
# 1984       10 Times Mongooses and Cobras Take the Stage
# 1985      10 Moments When Hyenas Brutally Attack Babies
# 1986  Wild Life - Lion Pride Documentary 2020 Full H...
# 1987  Lion Documentary - New Generation, Will They S...
#
#                                     snippet.description  \
# 0     England and Sri Lanka faced each other for the...
# 1     Young Boys and Galatasaray faced each other in...
# 2     Dynamo Kyiv and FC Salzburg faced each other i...
# 3     Bayer Leverkusen and VfB Stuttgart faced each ...
# 4     Real Madrid and Atalanta faced each other in t...
# ...                                                 ...
# 1983  The Big Blue - Ocean Stories from Down Under |...
# 1984       10 Times Mongooses and Cobras Take the Stage
# 1985      10 Moments When Hyenas Brutally Attack Babies
# 1986  National Geographic Documentary about Nsefu Li...
# 1987  Lionesses of Nsefu Pride are having a hard tim...
#
#                       snippet.thumbnails.default.url  \
# 0     https://i.ytimg.com/vi/aFqPPAZcB0g/default.jpg
# 1     https://i.ytimg.com/vi/h7w-DAjKIW4/default.jpg
# 2     https://i.ytimg.com/vi/01J6iADTaM0/default.jpg
# 3     https://i.ytimg.com/vi/cb6_MGRjx0o/default.jpg
# 4     https://i.ytimg.com/vi/_1W3_keYqK0/default.jpg
# ...                                              ...
# 1983  https://i.ytimg.com/vi/7RzoNyI17M4/default.jpg
# 1984  https://i.ytimg.com/vi/gZkcExDOQnY/default.jpg
# 1985  https://i.ytimg.com/vi/BV-6NBLVE6g/default.jpg
# 1986  https://i.ytimg.com/vi/4oavOSGo39w/default.jpg
# 1987  https://i.ytimg.com/vi/9c3d8BnTxHM/default.jpg
#
#       snippet.thumbnails.default.width  snippet.thumbnails.default.height  \
# 0                                  120                                 90
# 1                                  120                                 90
# 2                                  120                                 90
# 3                                  120                                 90
# 4                                  120                                 90
# ...                                ...                                ...
# 1983                               120                                 90
# 1984                               120                                 90
# 1985                               120                                 90
# 1986                               120                                 90
# 1987                               120                                 90
#
#       ... contentDetails.caption  contentDetails.licensedContent  \
# 0     ...                  false                            True
# 1     ...                  false                            True
# 2     ...                  false                            True
# 3     ...                  false                            True
# 4     ...                  false                            True
# ...   ...                    ...                             ...
# 1983  ...                  false                            True
# 1984  ...                  false                           False
# 1985  ...                  false                           False
# 1986  ...                  false                           False
# 1987  ...                  false                           False
#
#       contentDetails.regionRestriction.allowed contentDetails.projection  \
# 0         [AF, BD, BT, IN, LK, MM, MV, NP, PK]               rectangular
# 1             [AF, BD, BT, IN, LK, MV, NP, PK]               rectangular
# 2             [AF, BD, BT, IN, LK, MV, NP, PK]               rectangular
# 3                 [BD, BT, IN, LK, MV, NP, PK]               rectangular
# 4         [AF, BD, BT, IN, LK, MM, MV, NP, PK]               rectangular
# ...                                        ...                       ...
# 1983                                       NaN               rectangular
# 1984                                       NaN               rectangular
# 1985                                       NaN               rectangular
# 1986                                       NaN               rectangular
# 1987                                       NaN               rectangular
#
#       statistics.viewCount  statistics.likeCount statistics.commentCount  \
# 0                    77053                  2486                      24
# 1                      788                    32                       2
# 2                      184                     6                       0
# 3                     9472                   346                      10
# 4                   154382                  3837                      48
# ...                    ...                   ...                     ...
# 1983                 33153                   623                      24
# 1984                  1122                    18                       6
# 1985                  1361                    24                       5
# 1986                190573                  2882                     187
# 1987                354288                  4974                     340
#
#       contentDetails.regionRestriction.blocked  snippet.defaultLanguage  \
# 0                                          NaN                      NaN
# 1                                          NaN                      NaN
# 2                                          NaN                      NaN
# 3                                          NaN                      NaN
# 4                                          NaN                      NaN
# ...                                        ...                      ...
# 1983                                  [CN, NZ]                      NaN
# 1984                                       NaN                      NaN
# 1985                                       NaN                      NaN
# 1986                                       NaN                      NaN
# 1987                                       NaN                      NaN
#
#      contentDetails.contentRating.ytRating
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 1983                                   NaN
# 1984                                   NaN
# 1985                                   NaN
# 1986                                   NaN
# 1987                                   NaN
#
# [1988 rows x 42 columns]

# %%
final_df.to_csv("Data.csv")
